# %%
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Downloading scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 47.2 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.1 which is incompatible.
# Successfully installed scikit-learn-1.7.1

# %%
# !pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.10.2-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.5.1)
# Collecting pyaml>=16.9 (from scikit-optimize)
#   Downloading pyaml-25.7.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (2.0.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.16.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.7.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (25.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.6.0)
# Downloading scikit_optimize-0.10.2-py2.py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 2.7 MB/s eta 0:00:00
# Downloading pyaml-25.7.0-py3-none-any.whl (26 kB)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-25.7.0 scikit-optimize-0.10.2

# %%
# example of bayesian optimization with scikit-optimize
from numpy import mean
from sklearn.datasets import make_blobs
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from skopt.space import Integer
from skopt.utils import use_named_args
from skopt import gp_minimize

# %%
# generate 2d classification dataset
X, y = make_blobs(n_samples=500, centers=3, n_features=2)
# define the model
model = KNeighborsClassifier()
# define the space of hyperparameters to search
search_space = [Integer(1, 5, name='n_neighbors'), Integer(1, 2, name='p')]

# define the function used to evaluate a given configuration
@use_named_args(search_space)
def evaluate_model(**params):
 # something
 model.set_params(**params)
 # calculate 5-fold cross validation
 result = cross_val_score(model, X, y, cv=5, n_jobs=-1, scoring='accuracy')
 # calculate the mean of the scores
 estimate = mean(result)
 return 1.0 - estimate
# perform optimization
result = gp_minimize(evaluate_model, search_space)
# summarizing finding:
print('Best Accuracy: %.3f' % (1.0 - result.fun))
print('Best Parameters: n_neighbors=%d, p=%d' % (result.x[0], result.x[1]))
# Out:
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(2), np.int64(1)] before, using random point [np.int64(4), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(2), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(4), np.int64(2)] before, using random point [np.int64(2), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(1), np.int64(1)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(4), np.int64(2)] before, using random point [np.int64(3), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(5), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(3), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(2), np.int64(2)] before, using random point [np.int64(4), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(4), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(3), np.int64(2)] before, using random point [np.int64(3), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(3), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(2), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(2), np.int64(2)] before, using random point [np.int64(2), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(4), np.int64(2)] before, using random point [np.int64(1), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(3), np.int64(1)] before, using random point [np.int64(5), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(4), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(1), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(3), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(4), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(5), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(2), np.int64(1)] before, using random point [np.int64(2), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(3), np.int64(1)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(3), np.int64(2)] before, using random point [np.int64(4), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(3), np.int64(1)] before, using random point [np.int64(2), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(4), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(4), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(5), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(3), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(4), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(1), np.int64(1)] before, using random point [np.int64(3), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(1), np.int64(2)] before, using random point [np.int64(3), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(3), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(4), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(4), np.int64(2)] before, using random point [np.int64(3), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(3), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(5), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(3), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(4), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(3), np.int64(2)] before, using random point [np.int64(4), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(3), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(4), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(2), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(4), np.int64(1)] before, using random point [np.int64(2), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(2), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(1), np.int64(1)] before, using random point [np.int64(3), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(4), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(3), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(1), np.int64(2)] before, using random point [np.int64(3), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(5), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(5), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(1), np.int64(1)] before, using random point [np.int64(3), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(4), np.int64(1)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(2), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(1)] before, using random point [np.int64(5), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(4), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(2), np.int64(2)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(5), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(4), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(1), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(3), np.int64(2)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(2), np.int64(2)] before, using random point [np.int64(5), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(3), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(2), np.int64(2)] before, using random point [np.int64(2), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(4), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(1), np.int64(2)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(5), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(1), np.int64(1)] before, using random point [np.int64(2), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(4), np.int64(2)] before, using random point [np.int64(2), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(4), np.int64(2)] before, using random point [np.int64(2), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(2), np.int64(1)] before, using random point [np.int64(1), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(5), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(1), np.int64(2)] before, using random point [np.int64(5), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(3), np.int64(2)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(5), np.int64(2)] before, using random point [np.int64(3), np.int64(1)]
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/skopt/optimizer/optimizer.py:517: UserWarning: The objective has been evaluated at point [np.int64(3), np.int64(1)] before, using random point [np.int64(2), np.int64(2)]
#   warnings.warn(
# Best Accuracy: 0.906
# Best Parameters: n_neighbors=5, p=2
